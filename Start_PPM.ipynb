# %%
import powerplantmatching as pm
pm.data.DataUnits_CHP()
# Out:
# Cartopy not existent.
# DataUnits_CHP                    Name     Fueltype     Technology    Set  \
# 0                         PETERHEAD 1  Natural Gas  Steam Turbine     PP
# 1                         PETERHEAD 2  Natural Gas  Steam Turbine     PP
# 2              PETERHEAD REPOWER GT 1  Natural Gas           CCGT     PP
# 3              PETERHEAD REPOWER GT 2  Natural Gas           CCGT     PP
# 4              PETERHEAD REPOWER GT 3  Natural Gas           CCGT     PP
# ...                               ...          ...            ...    ...
# 6530                       Walchensee        Hydro      Reservoir  Store
# 6531                      Rosshaupten        Hydro      Reservoir  Store
# 6532                            Bigge        Hydro      Reservoir  Store
# 6533           RMVA Koeln Turbosatz 2        Waste  Steam Turbine    CHP
# 6534                      HKW West M5  Natural Gas  Steam Turbine     PP
#
# ...

# %%
import powerplantmatching as pm
pm.powerplants(update=True)
# Out:
# c:\Users\delic\powerplantmatching\powerplantmatching\data.py:2245: DtypeWarning: Columns (65,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file.open(name), usecols=usecols).assign(
# c:\Users\delic\powerplantmatching\powerplantmatching\matching.py:311: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   .stack(1, future_stack=True)
# c:\Users\delic\powerplantmatching\powerplantmatching\data.py:2245: DtypeWarning: Columns (65,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file.open(name), usecols=usecols).assign(
# Matched Data                     Name     Fueltype      Technology  Set  \
# ...

# %%
import powerplantmatching as pm
#pm.data.*()
#doesn't work: BNETZA, IRENA, CARMA, CARMA, GEO_units, IWPDCY, (OPSD_VRE_country), WEPP
# Out:
# ENTSOE          Name       Fueltype      Technology    Set         Country  \
# 0          Aanekoski  Solid Biomass             NaN     PP         Finland
# 1              Abono      Hard Coal             NaN     PP           Spain
# 2              Abono      Hard Coal             NaN     PP           Spain
# 3              Abthb      Hard Coal             NaN     PP  United Kingdom
# 4             Abthgt            Oil             NaN     PP  United Kingdom
# ...              ...            ...             ...    ...             ...
# 2233    Zielona Gora    Natural Gas            CCGT     PP          Poland
# 2234        Zofiowka      Hard Coal             NaN     PP          Poland
# 2235         Zolling      Hard Coal             NaN     PP         Germany
# 2236           Zuino          Hydro    Run-Of-River  Store           Italy
# 2237          Zydowo          Hydro  Pumped Storage  Store          Poland
#
# ...

# %%
from powerplantmatching.data import ENTSOE

df = ENTSOE(update=True)  # update=True erzwingt eine neue Abfrage bei ENTSO-E
print(df.head())
# Out:
# Cartopy not existent.
# Data for area(s) BY, CZ_DE_SK, HR, CWE, CY, DK, DK_1_NO_1, DE, IS, IT_SACO_AC, IT_SACO_DC, IT_BRNN, IT_FOGN, IT_GR, IT_MACRO_NORTH, IT_MACRO_SOUTH, IT_MALTA, IT_NORD_AT, IT_NORD_CH, IT_NORD_FR, IT_NORD_SI, IT_PRGP, IT_ROSN, RU_KGD, LU, MT, GB_IFA, GB_IFA2, GB_ELECLINK, UK, NO_1A, NO_2_NSL, NO_2A, PL_CZ, RU, TR, UA, UA_DOBTPP, DE_AMP_LU could not be retrieved.
# ENTSOE       Name       Fueltype Technology Set         Country  City  \
# 0       Aanekoski  Solid Biomass        NaN  PP         Finland   NaN
# 1             Abo      Hard Coal        NaN  PP           Spain   NaN
# 2             Abo      Hard Coal        NaN  PP           Spain   NaN
# 3           Abrbo           Wind   Offshore  PP  United Kingdom   NaN
# 4           Abrtw           Wind    Onshore  PP  United Kingdom   NaN
#
# ENTSOE  Capacity  HeatCapacity  Efficiency  DateIn  DateRetrofit  DateOut  \
# 0          260.0           NaN         NaN     NaN           NaN      NaN
# ...
